# %%
# Press 1 to eneter a student
# press 2 to search a student
# press 3 to print all
# press 4 to del a student
# press 5 to quit

# %%
students = {}

# %%
flag = True
while flag:
    u_input = int(input("Enter a number to select mode"))
    if u_input == 5:
        print("Exiting Program : See you Again")
        flag = False
    elif u_input == 1:
        print("**********")
        print("Entering new student data")
        student_reg = input("Enter student registration number")
        student_name = input("Enter student name")
        student_father_name = input("Enter student father name")
        student_age = input("Enter student age")
        student_course = input("Enter student course")
        students[student_reg] = {}
        students[student_reg]["Name"] = student_name
        students[student_reg]["Father Name"] = student_father_name
        students[student_reg]["Age"] = student_age
        students[student_reg]["Course"] = student_course
        print("**********")
    elif u_input == 2:
        print("**********")
        print("Getting student data")
        student_reg = input("Enter student registration number")
        print("Registration No. => ", student_reg)
        print("**********")
        for k,v in students[student_reg].items():
            print(k, " => ",v)
        print("**********")
    elif u_input == 3:
        for kk in students:
            print("**********")
            print("Getting all students data")
            print("**********")
            print("Registration No. => ", kk)
            for k,v in students[kk].items():
                print(k, " => ",v)
            print("**********")
    elif u_input == 4:
        print("**********")
        print("Deleting a student")
        print("**********")
        student_reg = input("Enter student registration number")
        print("Registration No. => ", student_reg, "--- Deleted")
        del students[student_reg]
        print("**********")
# Out:
# **********
# Entering new student data
# **********
# **********
# Entering new student data
# **********
# **********
# Entering new student data
# **********
# **********
# Getting student data
# Registration No. =>  3
# **********
# Name  =>  Umair
# Father Name  =>  Hafeez
# Age  =>  28
# Course  =>  CNC
# **********
# **********
# Getting all students data
# **********
# Registration No. =>  1
# Name  =>  Hassan
# Father Name  =>  Zaheer
# Age  =>  29
# Course  =>  AI
# **********
# **********
# Getting all students data
# **********
# Registration No. =>  2
# Name  =>  Zubair
# Father Name  =>  Abdul
# Age  =>  25
# Course  =>  BCC
# **********
# **********
# Getting all students data
# **********
# Registration No. =>  3
# Name  =>  Umair
# Father Name  =>  Hafeez
# Age  =>  28
# Course  =>  CNC
# **********
# **********
# Deleting a student
# **********
# Registration No. =>  3 --- Deleted
# **********
# **********
# Getting all students data
# **********
# Registration No. =>  1
# Name  =>  Hassan
# Father Name  =>  Zaheer
# Age  =>  29
# Course  =>  AI
# **********
# **********
# Getting all students data
# **********
# Registration No. =>  2
# Name  =>  Zubair
# Father Name  =>  Abdul
# Age  =>  25
# Course  =>  BCC
# **********
# Exiting Program : See you Again
